# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import sys

# %% [markdown]
# ### pfrlライブラリのパスへの追加

# %%
sys.path.append("/content/gdrive/MyDrive/repos/pfrl")

# %% [markdown]
# ### インポート

# %%
import pfrl
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# %%
import cv2
from pathlib import Path

# %%
from tqdm.notebook import tqdm

# %% [markdown]
# ### 描画のための処理

# %% [markdown]
# [こちら](https://stackoverflow.com/a/61318224)あるいは[こちら](https://stackoverflow.com/a/61318224)を参考にした．

# %%
# !apt-get install -y xvfb x11-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# x11-utils is already the newest version (7.7+3build1).
# xvfb is already the newest version (2:1.19.6-1ubuntu4.8).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %%
# !pip install -q gym[box2d]==0.17.* pyvirtualdisplay==0.2.* PyOpenGL==3.1.* PyOpenGL-accelerate==3.1.*

# %%
import pyvirtualdisplay
_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
                                    size=(1400, 900))
_ = _display.start()

# %% [markdown]
# ### 環境の作成

# %% [markdown]
# 今回はカートポールの環境を利用する．状態は [カートの位置，加速度，ポールの角度，ポールの角速度] の連続値．行動は左右のどちらへ移動するかの離散値

# %%
import gym

# %%
env = gym.make("CartPole-v0")
print("observation space:", env.observation_space)
print("action space:", env.action_space)
# Out:
# observation space: Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)
# action space: Discrete(2)

# %% [markdown]
# #### 最初の状態を観測

# %%
obs = env.reset()
print("initial observation:", obs)
# Out:
# initial observation: [ 0.0411939   0.01694667  0.00651279 -0.02487047]

# %% [markdown]
# #### 適当な行動からObservation, rewardを取得

# %%
action = env.action_space.sample()
obs, r, done, info = env.step(action)
print("next obserbation:", obs)
print("reward:", r)
print("done:", done)
print("info:", info)
# Out:
# next obserbation: [ 0.04153283  0.21197462  0.00601538 -0.31549144]
# reward: 1.0
# done: False
# info: {}

# %% [markdown]
# ### ランダム行動の可視化

# %%
fourcc = cv2.VideoWriter_fourcc('m', 'p', '4', 'v')
out = cv2.VideoWriter('/content/gdrive/MyDrive/rl_tutorial/movies/pfrl_tutorial_dqn.mp4', fourcc, 10, (600, 400))

max_episode_len = 200

R = 0  # Return (sum ofrewards)
t = 0  # time stepa
env.reset()

while True:
    action = env.action_space.sample()
    obs, reward, done, _ = env.step(action)
    R += reward
    t += 1
    reset = t == max_episode_len
    # 画像として取得，保存
    frame = env.render(mode="rgb_array")
    out.write(frame[:,:,::-1])
    
    if done or reset:
        break
        
env.close()
out.release()

print("episode length:", t)
# Out:
# episode length: 29

# %% [markdown]
# ### Q関数の定義

# %% [markdown]
# ここで，最終行の`pfrl.action_value.DiscreteActionValue`とは，`torch.Tensor`をラップするクラスで，エージェント内部でのQ関数の値の扱いを簡単にするために利用する．そのため，Q関数の値によって方策を決定する手法のすべてでQ関数モデルの出力値をラップする必要がある．Q関数を方策の決定に用いない場合は付けるべきでない？

# %%
class MyQFunction(nn.Module):
    def __init__(self, obs_size, n_actions):
        super().__init__()
        self.fc1 = nn.Linear(obs_size, 50)
        self.fc2 = nn.Linear(50, 50)
        self.fc3 = nn.Linear(50, n_actions)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        out = pfrl.action_value.DiscreteActionValue(x)
        return out

# %%
obs_size = env.observation_space.low.size
print("observation size:", obs_size)
n_actions = env.action_space.n
print("action size:",n_actions)
q_func = MyQFunction(obs_size, n_actions)
# Out:
# observation size: 4
# action size: 2

# %% [markdown]
# ### エージェントの作成

# %%
optimizer = torch.optim.Adam(q_func.parameters(), eps=1e-2)

# %%
gamma = 0.9

explorer = pfrl.explorers.ConstantEpsilonGreedy(epsilon=0.3,
                                                random_action_func=env.action_space.sample
                                               )

replay_buffer = pfrl.replay_buffers.ReplayBuffer(capacity=10**6)

phi = lambda x: x.astype(np.float32, copy=False)

gpu = -1 # -1 is cpu

agent = pfrl.agents.DoubleDQN(
    q_function=q_func,
    optimizer=optimizer,
    replay_buffer=replay_buffer,
    gamma=gamma,
    explorer=explorer,
    replay_start_size=500,
    update_interval=1,
    target_update_interval=100,
    phi=phi,
    gpu=gpu
)

# %% [markdown]
# ### 学習のイテレーション

# %% [markdown]
# breakの判定ではdoneとreset(指定ステップに到達)のどちらかあるいはresetのみを利用してもよい．これは`agent.observe`がdoneを考慮できるからである．しかし環境側は追加してstepしてしまうのでwarningが出る．そのため煩わしいならそのwarningを非表示にするなどを検討する．

# %%
n_episodes = 1000  # エピソードの回数
max_episode_len = 200
for i in tqdm(range(1, n_episodes + 1)):
    obs = env.reset()  # 観測のリセット
    R = 0  # Return (sum ofrewards)
    t = 0  # time step
    while True:
        action = agent.act(obs)
        obs, reward, done, _ = env.step(action)
        R += reward
        t += 1
        reset = t == max_episode_len
        agent.observe(obs, reward, done, reset)
        if done or reset:  # どちらでも良い
        #if reset:  # こちらがwarnが出る
            break
    
    if i%10 == 0:
        print("episode:{}, return:{}".format(i, R))
    if i%50 == 0:
        print("statistics:", agent.get_statistics())
        
print("Finshed")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# episode:10, return:15.0
# episode:20, return:10.0
# episode:30, return:12.0
# episode:40, return:13.0
# episode:50, return:11.0
# statistics: [('average_q', 0.5866759), ('average_loss', 0.2298720313631224), ('cumulative_steps', 565), ('n_updates', 66), ('rlen', 565)]
# episode:60, return:11.0
# episode:70, return:12.0
# episode:80, return:14.0
# episode:90, return:10.0
# episode:100, return:8.0
# statistics: [('average_q', 4.683429), ('average_loss', 0.22156397092621774), ('cumulative_steps', 1163), ('n_updates', 664), ('rlen', 1163)]
# episode:110, return:12.0
# episode:120, return:10.0
# episode:130, return:27.0
# episode:140, return:21.0
# episode:150, return:200.0
# statistics: [('average_q', 9.063849), ('average_loss', 0.2922391359321773), ('cumulative_steps', 2904), ('n_updates', 2405), ('rlen', 2904)]
# episode:160, return:32.0
# episode:170, return:111.0
# episode:180, return:62.0
# episode:190, return:200.0
# episode:200, return:200.0
# statistics: [('average_q', 9.922631), ('average_loss', 0.10506204106030054), ('cumulative_steps', 8505), ('n_updates', 8006), ('rlen', 8505)]
# episode:210, return:183.0
# episode:220, return:170.0
# episode:230, return:200.0
# episode:240, return:200.0
# episode:250, return:200.0
# statistics: [('average_q', 10.12183), ('average_loss', 0.07925716620869934), ('cumulative_steps', 16616), ('n_updates', 16117), ('rlen', 16616)]
# episode:260, return:200.0
# episode:270, return:200.0
# episode:280, return:200.0
# episode:290, return:37.0
# episode:300, return:169.0
# statistics: [('average_q', 10.004533), ('average_loss', 0.07432424436236033), ('cumulative_steps', 25925), ('n_updates', 25426), ('rlen', 25925)]
# episode:310, return:177.0
# episode:320, return:200.0
# episode:330, return:53.0
# episode:340, return:104.0
# episode:350, return:173.0
# statistics: [('average_q', 9.917596), ('average_loss', 0.0803274796664482), ('cumulative_steps', 33093), ('n_updates', 32594), ('rlen', 33093)]
# episode:360, return:149.0
# episode:370, return:141.0
# episode:380, return:35.0
# episode:390, return:34.0
# episode:400, return:17.0
# statistics: [('average_q', 10.017785), ('average_loss', 0.05827564561535837), ('cumulative_steps', 38341), ('n_updates', 37842), ('rlen', 38341)]
# episode:410, return:124.0
# episode:420, return:130.0
# episode:430, return:51.0
# episode:440, return:79.0
# episode:450, return:18.0
# statistics: [('average_q', 9.920996), ('average_loss', 0.06616815550427418), ('cumulative_steps', 42937), ('n_updates', 42438), ('rlen', 42937)]
# episode:460, return:60.0
# episode:470, return:25.0
# episode:480, return:119.0
# episode:490, return:56.0
# episode:500, return:23.0
# statistics: [('average_q', 10.012581), ('average_loss', 0.05994503627123777), ('cumulative_steps', 46326), ('n_updates', 45827), ('rlen', 46326)]
# episode:510, return:28.0
# episode:520, return:12.0
# episode:530, return:21.0
# episode:540, return:91.0
# episode:550, return:120.0
# statistics: [('average_q', 10.017939), ('average_loss', 0.05016634823288769), ('cumulative_steps', 49468), ('n_updates', 48969), ('rlen', 49468)]
# episode:560, return:119.0
# episode:570, return:60.0
# episode:580, return:38.0
# episode:590, return:13.0
# episode:600, return:14.0
# statistics: [('average_q', 9.989581), ('average_loss', 0.05812319197342731), ('cumulative_steps', 53312), ('n_updates', 52813), ('rlen', 53312)]
# episode:610, return:67.0
# episode:620, return:122.0
# episode:630, return:115.0
# episode:640, return:29.0
# episode:650, return:117.0
# statistics: [('average_q', 9.94649), ('average_loss', 0.05618092459626496), ('cumulative_steps', 57062), ('n_updates', 56563), ('rlen', 57062)]
# episode:660, return:52.0
# episode:670, return:15.0
# episode:680, return:17.0
# episode:690, return:45.0
# episode:700, return:13.0
# statistics: [('average_q', 9.876963), ('average_loss', 0.07080705400323495), ('cumulative_steps', 60891), ('n_updates', 60392), ('rlen', 60891)]
# episode:710, return:200.0
# episode:720, return:115.0
# episode:730, return:37.0
# episode:740, return:31.0
# episode:750, return:139.0
# statistics: [('average_q', 9.913037), ('average_loss', 0.07543336664151866), ('cumulative_steps', 64500), ('n_updates', 64001), ('rlen', 64500)]
# episode:760, return:163.0
# episode:770, return:9.0
# episode:780, return:42.0
# episode:790, return:115.0
# episode:800, return:12.0
# statistics: [('average_q', 9.962988), ('average_loss', 0.04871664480655454), ('cumulative_steps', 68008), ('n_updates', 67509), ('rlen', 68008)]
# episode:810, return:69.0
# episode:820, return:14.0
# episode:830, return:12.0
# episode:840, return:11.0
# episode:850, return:14.0
# statistics: [('average_q', 9.9529505), ('average_loss', 0.049419134473428133), ('cumulative_steps', 70810), ('n_updates', 70311), ('rlen', 70810)]
# episode:860, return:19.0
# episode:870, return:62.0
# episode:880, return:13.0
# episode:890, return:15.0
# episode:900, return:72.0
# statistics: [('average_q', 9.973197), ('average_loss', 0.08068529248994309), ('cumulative_steps', 73573), ('n_updates', 73074), ('rlen', 73573)]
# episode:910, return:17.0
# episode:920, return:52.0
# episode:930, return:18.0
# episode:940, return:106.0
# episode:950, return:12.0
# statistics: [('average_q', 9.831975), ('average_loss', 0.06742581591650378), ('cumulative_steps', 76353), ('n_updates', 75854), ('rlen', 76353)]
# episode:960, return:128.0
# episode:970, return:14.0
# episode:980, return:14.0
# episode:990, return:14.0
# episode:1000, return:20.0
# statistics: [('average_q', 9.874683), ('average_loss', 0.07239661975065247), ('cumulative_steps', 78526), ('n_updates', 78027), ('rlen', 78526)]
#
# Finshed

# %% [markdown]
# ### 学習結果の可視化

# %%
fourcc = cv2.VideoWriter_fourcc('m', 'p', '4', 'v')
out = cv2.VideoWriter('/content/gdrive/MyDrive/rl_tutorial/movies/pfrl_tutorial_dqn_result.mp4', fourcc, 10, (600, 400))

max_episode_len = 200
with agent.eval_mode():
    
    obs = env.reset()  # 観測のリセット
    R = 0  # Return (sum ofrewards)
    t = 0  # time step
    
    while True:
        action = agent.act(obs)
        obs, reward, done, _ = env.step(action)
        R += reward
        t += 1
        reset = t == max_episode_len
        # 画像として取得，保存
        frame = env.render(mode="rgb_array")
        out.write(frame[:,:,::-1])       
        
        #agent.observe(obs, reward, done, reset)
        if done or reset:
            break
            
env.close()
out.release()

print("episode length:", t)
# Out:
# episode length: 126

# %% [markdown]
# ### エージェントの保存

# %%
save_path = Path("tutorial_agents") / Path("pfrl_tutorial_dpn")
agent.save(save_path)

# %% [markdown]
# ### 他のモデルもお試し

# %% [markdown]
# #### Rainbow
